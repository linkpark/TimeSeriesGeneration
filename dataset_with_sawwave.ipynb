# %%
# Check that imports for the rest of the file work.
import tensorflow as tf
import tensorflow_gan as tfgan
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import numpy as np
import time
import utils

# %matplotlib inline
import matplotlib.pyplot as plt

from rnngan import LSTMTFGAN

import warnings
warnings.filterwarnings('ignore')
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1023 15:57:51.734772 17876 deprecation_wrapper.py:119] From C:\Users\jw855-admin\AppData\Local\conda\conda\envs\huawei\lib\site-packages\tensorflow_gan\python\contrib_utils.py:305: The name tf.estimator.tpu.TPUEstimator is deprecated. Please use tf.compat.v1.estimator.tpu.TPUEstimator instead.
#
# W1023 15:57:51.737763 17876 deprecation_wrapper.py:119] From C:\Users\jw855-admin\AppData\Local\conda\conda\envs\huawei\lib\site-packages\tensorflow_gan\python\contrib_utils.py:310: The name tf.estimator.tpu.TPUEstimatorSpec is deprecated. Please use tf.compat.v1.estimator.tpu.TPUEstimatorSpec instead.
#
# W1023 15:57:53.448599 17876 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# A sawtooth can be constructed using additive synthesis. The infinite Fourier series
#
# $$x(t) = \frac{2A}{\pi} \sum_{k=1}^{\infty}(-1)^k \frac{sin(2\pi k f t)}{k}$$
#
# we call the $scipy.signal.sawtooth$ to generate the sawtooth.

# %%
# hyperparamters setting
# we set the buffer size as 1000
hparams = tf.contrib.training.HParams(
            is_training=True,
            batch_size=50,
            buffer_size=1000,
            sequence_length=50,
            epoch=6000,
            noise_dim=5,
            num_units=128,
            gan_loss = 'min_max',
            d_lr=1e-4,
            g_lr=1e-3,
            generator_train_steps = 1,
            discriminator_train_steps = 5,
            interval=1200,
            num_eval=128
        )

train_sequence = utils.sine_wave_plus_sawtooth(seq_length=hparams.sequence_length, num_samples=hparams.buffer_size)
train_dataset = tf.data.Dataset.from_tensor_slices(train_sequence).shuffle(hparams.buffer_size).batch(hparams.batch_size)
iterator = tf.compat.v1.data.make_initializable_iterator(train_dataset)
real_sequence = iterator.get_next()

# %%
sess = tf.Session()
sess.run(iterator.initializer)
result = np.array(sess.run(real_sequence))

# create the anomaly with sawwave (half sequence is sinewave, another half is the superposition of sinewave and saw wave) 
utils.plot_sample_sequence(result, 5, 5, fig_title='Examples from Real Dataset')

# %%
# Define the training model for RNNGAN
noise_input = tf.random_normal([hparams.batch_size, hparams.sequence_length, hparams.noise_dim])
seq_gan = LSTMTFGAN(train_dataset, noise_input, hparams)
# Out:
# W1023 15:57:57.710626 17876 deprecation_wrapper.py:119] From D:\Code\Deep-Generative-models\rnn-tf-gan\rnngan.py:18: The name tf.data.make_initializable_iterator is deprecated. Please use tf.compat.v1.data.make_initializable_iterator instead.
#
# W1023 15:57:57.725714 17876 deprecation.py:323] From D:\Code\Deep-Generative-models\rnn-tf-gan\rnngan.py:22: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# W1023 15:57:57.727678 17876 deprecation.py:323] From D:\Code\Deep-Generative-models\rnn-tf-gan\rnngan.py:26: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# W1023 15:57:57.793501 17876 deprecation.py:506] From C:\Users\jw855-admin\AppData\Local\conda\conda\envs\huawei\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W1023 15:57:57.807463 17876 deprecation.py:506] From C:\Users\jw855-admin\AppData\Local\conda\conda\envs\huawei\lib\site-packages\tensorflow\python\ops\rnn_cell_impl.py:961: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W1023 15:57:58.315826 17876 deprecation.py:323] From D:\Code\Deep-Generative-models\rnn-tf-gan\rnngan.py:29: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W1023 15:57:58.800458 17876 deprecation.py:323] From C:\Users\jw855-admin\AppData\Local\conda\conda\envs\huawei\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1023 15:57:58.893994 17876 deprecation_wrapper.py:119] From D:\Code\Deep-Generative-models\rnn-tf-gan\rnngan.py:67: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W1023 15:57:59.238284 17876 deprecation.py:323] From C:\Users\jw855-admin\AppData\Local\conda\conda\envs\huawei\lib\site-packages\tensorflow_gan\python\contrib_utils.py:56: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# W1023 15:57:59.721687 17876 deprecation_wrapper.py:119] From D:\Code\Deep-Generative-models\rnn-tf-gan\rnngan.py:77: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W1023 15:57:59.737331 17876 deprecation_wrapper.py:119] From D:\Code\Deep-Generative-models\rnn-tf-gan\rnngan.py:79: The name tf.random_normal is deprecated. Please use tf.random.normal instead.

# %%
seq_gan.train(visualization=True)
# Out:
# W1023 15:57:59.842164 17876 deprecation_wrapper.py:119] From D:\Code\Deep-Generative-models\rnn-tf-gan\rnngan.py:95: The name tf.train.get_or_create_global_step is deprecated. Please use tf.compat.v1.train.get_or_create_global_step instead.
#
# W1023 15:57:59.842164 17876 deprecation_wrapper.py:119] From D:\Code\Deep-Generative-models\rnn-tf-gan\rnngan.py:100: The name tf.train.SingularMonitoredSession is deprecated. Please use tf.compat.v1.train.SingularMonitoredSession instead.
# Current loss: 5.925119
# Training step: 0
# Time since start: 0.023133 m
# Steps per min: 0.000000
# Current loss: 4.454778
# Training step: 5994
# Time since start: 33.881827 m
# Steps per min: 176.908996
# Current loss: 4.191460
# Training step: 11994
# Time since start: 65.827890 m
# Steps per min: 182.202406
# Current loss: 4.663427
# Training step: 17994
# Time since start: 99.593152 m
# Steps per min: 180.675073
# Current loss: 4.532403
# Training step: 23994
# Time since start: 133.340434 m
# Steps per min: 179.945417
# Current loss: 5.048852
# Training step: 29994
# Time since start: 166.978112 m
# Steps per min: 179.628334
